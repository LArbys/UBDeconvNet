# %%
import caffe
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

caffe.set_device(2)
caffe.set_mode_gpu()

# %%
solver = caffe.SGDSolver("solver.prototxt")
WEIGHTS = "/stage/vgenty/snapshot_rmsprop_iter_20000.caffemodel"
solver.net.copy_from(WEIGHTS)

# %%
for i in xrange(100):
    solver.step(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-3a59d5915560> in <module>()
#       1 for i in xrange(100):
# ----> 2     solver.step(1)
#
# KeyboardInterrupt:

# %%
k=3
plt.imshow(solver.net.blobs['data'].data[k][0],cmap="Greys",interpolation=None)
plt.show()
plt.imshow(solver.net.blobs['label'].data[k][0],cmap="Greys",interpolation=None)
plt.show()

# %%
k=3
for i in xrange(6):
    fig,ax = plt.subplots(figsize=(5,5))
    oo = solver.net.blobs['score'].data[k][i]
    plt.imshow(oo.astype(np.uint8),cmap="Greys_r",interpolation=None)

    print oo.max(),oo.min()
    #ax.hist(oo.flatten())
    #ax.set_yscale('log')
    #plt.colorbar()
    plt.show()
# Out:
# 6.85334 5.44929
# 0.126456 -0.847753
# 0.135283 -1.01952
# -1.00519 -2.11823
# -1.28127 -1.31903
# -1.25809 -1.71309

# %%
k=3
for i in xrange(100):
    plt.imshow(solver.net.blobs['unpool2'].data[k][i],cmap="Greys",interpolation=None)
    plt.show()
